# %% [markdown]
# Stock Market Analysis

# %% [markdown]
# importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
DATA_PATH  =  '/kaggle/input/nifty50-stock-market-data/HDFCBANK.csv'

# %%
hdfcbank = pd.read_csv('/content/drive/MyDrive/HDFC.csv')

# %%
hdfcbank.head()
# Out:
#          Date Symbol Series  Prev Close   Open    High    Low   Last   Close  \
# 0  2000-01-03   HDFC     EQ      271.75  293.5  293.50  293.5  293.5  293.50
# 1  2000-01-04   HDFC     EQ      293.50  317.0  317.00  297.0  304.0  304.05
# 2  2000-01-05   HDFC     EQ      304.05  290.0  303.90  285.0  295.0  292.80
# 3  2000-01-06   HDFC     EQ      292.80  301.0  314.00  295.0  296.0  296.45
# 4  2000-01-07   HDFC     EQ      296.45  290.0  296.35  281.0  287.1  286.55
#
#      VWAP  Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  293.50   22744  6.675364e+11     NaN                 NaN          NaN
# 1  303.62  255251  7.749972e+12     NaN                 NaN          NaN
# 2  294.53  269087  7.925368e+12     NaN                 NaN          NaN
# 3  300.14  305916  9.181669e+12     NaN                 NaN          NaN
# 4  288.80  197039  5.690480e+12     NaN                 NaN          NaN

# %%
hdfcbank.tail()
# Out:
#             Date Symbol Series  Prev Close     Open    High      Low     Last  \
# 5301  2021-04-26   HDFC     EQ     2497.35  2500.00  2534.1  2483.20  2502.00
# 5302  2021-04-27   HDFC     EQ     2509.80  2494.15  2526.8  2486.25  2514.00
# 5303  2021-04-28   HDFC     EQ     2518.40  2516.10  2609.0  2508.30  2575.00
# 5304  2021-04-29   HDFC     EQ     2577.00  2590.90  2628.0  2533.00  2539.70
# 5305  2021-04-30   HDFC     EQ     2538.85  2503.10  2525.0  2411.10  2433.25
#
#         Close     VWAP   Volume      Turnover    Trades  Deliverable Volume  \
# 5301  2509.80  2508.07  3916088  9.821805e+14  121028.0           2440395.0
# 5302  2518.40  2509.18  2040799  5.120730e+14  102250.0           1040749.0
# 5303  2577.00  2574.21  3407461  8.771527e+14  117425.0           1815110.0
# 5304  2538.85  2569.65  3005468  7.722995e+14  132826.0           1472924.0
# 5305  2420.10  2445.94  6024595  1.473581e+15  224454.0           3839105.0
#
#       %Deliverble
# 5301       0.6232
# ...

# %%
# Visualizing the using heatmap
sns.heatmap(hdfcbank.isnull(), yticklabels = False, cbar= False, cmap = 'viridis').set_title('No. of null values in data');

# %%
#  Ploting heat map of correlation values between target columns vs null value columns
## Furst target column is : Volumn
null_cols = ['Volume','Trades','Deliverable Volume','%Deliverble']
corr_1 = hdfcbank[null_cols].corr()
sns.heatmap(corr_1, annot  = True);

# %%
#  Ploting heat map of correlation values between target columns vs null value columns
## Furst target column is : Open
null_cols = ['Open','Trades','Deliverable Volume','%Deliverble']
corr_1 = hdfcbank[null_cols].corr()
sns.heatmap(corr_1, annot = True);

# %%
DATA_PATH  =  '/kaggle/input/nifty50-stock-market-data/ADANIPORTS.csv'

# %%
adaniports = pd.read_csv('/content/drive/MyDrive/ADANIPORTS.csv')

# %%
adaniports.head()
# Out:
#          Date      Symbol Series  Prev Close    Open     High    Low   Last  \
# 0  2007-11-27  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.0  959.0
# 1  2007-11-28  MUNDRAPORT     EQ      962.90  984.00   990.00  874.0  885.0
# 2  2007-11-29  MUNDRAPORT     EQ      893.90  909.00   914.75  841.0  887.0
# 3  2007-11-30  MUNDRAPORT     EQ      884.20  890.00   958.00  890.0  929.0
# 4  2007-12-03  MUNDRAPORT     EQ      921.55  939.75   995.00  922.0  980.0
#
#     Close    VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# 0  962.90  984.72  27294366  2.687719e+15     NaN             9859619
# 1  893.90  941.38   4581338  4.312765e+14     NaN             1453278
# 2  884.20  888.09   5124121  4.550658e+14     NaN             1069678
# 3  921.55  929.17   4609762  4.283257e+14     NaN             1260913
# 4  969.30  965.65   2977470  2.875200e+14     NaN              816123
#
#    %Deliverble
# 0       0.3612
# 1       0.3172
# 2       0.2088
# 3       0.2735
# ...

# %%
adaniports.tail()
# Out:
#             Date      Symbol Series  Prev Close   Open    High     Low   Last  \
# 3317  2021-04-26  ADANIPORTS     EQ      725.35  733.0  739.65  728.90  729.2
# 3318  2021-04-27  ADANIPORTS     EQ      730.75  735.0  757.50  727.35  748.6
# 3319  2021-04-28  ADANIPORTS     EQ      749.15  755.0  760.00  741.10  743.4
# 3320  2021-04-29  ADANIPORTS     EQ      746.25  753.2  765.85  743.40  746.4
# 3321  2021-04-30  ADANIPORTS     EQ      746.75  739.0  759.45  724.50  726.4
#
#        Close    VWAP    Volume      Turnover    Trades  Deliverable Volume  \
# 3317  730.75  733.25   9390549  6.885658e+14  116457.0              838079
# 3318  749.15  747.67  20573107  1.538191e+15  236896.0             1779639
# 3319  746.25  751.02  11156977  8.379106e+14  130847.0             1342353
# 3320  746.75  753.06  13851910  1.043139e+15  153293.0             1304895
# 3321  730.05  743.35  12600934  9.366911e+14  132141.0             3514692
#
#       %Deliverble
# 3317       0.0892
# ...

# %%
# Visualizing the using heatmap
sns.heatmap(adaniports.isnull(), yticklabels = False, cbar= False, cmap = 'viridis').set_title('No. of null values in data');

# %%
# Ploting heat map of correlation values between target columns vs null value columns
## Furst target column is : Volumn
null_cols = ['Volume','Trades','Deliverable Volume','%Deliverble']
corr_1 = adaniports[null_cols].corr()
sns.heatmap(corr_1, annot  = True);

# %%
#Ploting heat map of correlation values between target columns vs null value columns
## Furst target column is : Open
null_cols = ['Open','Trades','Deliverable Volume','%Deliverble']
corr_1 = adaniports[null_cols].corr()
sns.heatmap(corr_1, annot = True);

# %%
DATA_PATH  = '/kaggle/input/nifty50-stock-market-data/ASIANPAINT.csv'

# %%
asianpaint = pd.read_csv('/content/drive/MyDrive/ASIANPAINT.csv')

# %%
asianpaint.head()
# Out:
#          Date      Symbol Series  Prev Close   Open   High    Low   Last  \
# 0  2000-01-03  ASIANPAINT     EQ      361.20  370.0  390.0  370.0  385.0
# 1  2000-01-04  ASIANPAINT     EQ      381.65  380.0  392.0  375.0  390.0
# 2  2000-01-05  ASIANPAINT     EQ      385.55  371.5  390.0  371.5  383.0
# 3  2000-01-06  ASIANPAINT     EQ      383.00  384.9  384.9  374.5  375.1
# 4  2000-01-07  ASIANPAINT     EQ      377.50  376.0  390.0  370.0  389.0
#
#     Close    VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 0  381.65  380.54    3318  1.262617e+11     NaN                 NaN
# 1  385.55  383.50    4818  1.847699e+11     NaN                 NaN
# 2  383.00  379.81    2628  9.981384e+10     NaN                 NaN
# 3  377.50  379.88    3354  1.274114e+11     NaN                 NaN
# 4  385.70  383.38    9589  3.676275e+11     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
asianpaint.tail()
# Out:
#             Date      Symbol Series  Prev Close    Open     High      Low  \
# 5301  2021-04-26  ASIANPAINT     EQ     2517.95  2530.0  2575.00  2530.00
# 5302  2021-04-27  ASIANPAINT     EQ     2557.90  2545.0  2579.90  2534.00
# 5303  2021-04-28  ASIANPAINT     EQ     2574.35  2588.0  2620.25  2575.00
# 5304  2021-04-29  ASIANPAINT     EQ     2614.55  2630.0  2642.00  2570.00
# 5305  2021-04-30  ASIANPAINT     EQ     2613.45  2595.0  2605.80  2524.05
#
#         Last    Close     VWAP   Volume      Turnover   Trades  \
# 5301  2558.0  2557.90  2557.47  1103980  2.823400e+14  58557.0
# 5302  2571.0  2574.35  2560.55   866331  2.218288e+14  66988.0
# 5303  2612.0  2614.55  2605.91  1065561  2.776752e+14  52622.0
# 5304  2613.0  2613.45  2607.33  1295346  3.377394e+14  64039.0
# 5305  2529.0  2536.40  2558.66  1384907  3.543512e+14  91934.0
#
#       Deliverable Volume  %Deliverble
# 5301            335232.0       0.3037
# 5302            281178.0       0.3246
# ...

# %%
# Visualizing the using heatmap
sns.heatmap(asianpaint.isnull(), yticklabels = False, cbar= False, cmap = 'viridis').set_title('No. of null values in data');

# %%
# Ploting heat map of correlation values between target columns vs null value columns
## Furst target column is : Volumn
null_cols = ['Volume','Trades','Deliverable Volume','%Deliverble']
corr_1 = asianpaint[null_cols].corr()
sns.heatmap(corr_1, annot  = True);

# %%
# Ploting heat map of correlation values between target columns vs null value columns
## Furst target column is : Open
null_cols = ['Open','Trades','Deliverable Volume','%Deliverble']
corr_1 = asianpaint[null_cols].corr()
sns.heatmap(corr_1, annot = True);

# %%
DATA_PATH  =  '/kaggle/input/nifty50-stock-market-data/AXISBANK.csv'

# %%
axisbank = pd.read_csv('/content/drive/MyDrive/AXISBANK.csv')

# %%
axisbank.head()
# Out:
#          Date   Symbol Series  Prev Close  Open   High    Low  Last  Close  \
# 0  2000-01-03  UTIBANK     EQ       24.70  26.7  26.70  26.70  26.7  26.70
# 1  2000-01-04  UTIBANK     EQ       26.70  27.0  28.70  26.50  27.0  26.85
# 2  2000-01-05  UTIBANK     EQ       26.85  26.0  27.75  25.50  26.4  26.30
# 3  2000-01-06  UTIBANK     EQ       26.30  25.8  27.00  25.80  25.9  25.95
# 4  2000-01-07  UTIBANK     EQ       25.95  25.0  26.00  24.25  25.0  24.80
#
#     VWAP  Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  26.70  112100  2.993070e+11     NaN                 NaN          NaN
# 1  27.24  234500  6.387275e+11     NaN                 NaN          NaN
# 2  26.24  170100  4.462980e+11     NaN                 NaN          NaN
# 3  26.27  102100  2.681730e+11     NaN                 NaN          NaN
# 4  25.04   62600  1.567220e+11     NaN                 NaN          NaN

# %%
axisbank.tail()
# Out:
#             Date    Symbol Series  Prev Close   Open    High     Low    Last  \
# 5301  2021-04-26  AXISBANK     EQ      671.35  694.0  703.80  684.50  699.50
# 5302  2021-04-27  AXISBANK     EQ      700.45  691.1  703.90  684.10  700.90
# 5303  2021-04-28  AXISBANK     EQ      699.55  708.0  712.50  688.15  705.95
# 5304  2021-04-29  AXISBANK     EQ      708.15  712.0  726.90  707.00  717.10
# 5305  2021-04-30  AXISBANK     EQ      719.40  705.0  729.85  705.00  711.65
#
#        Close    VWAP    Volume      Turnover    Trades  Deliverable Volume  \
# 5301  700.45  695.33  21646184  1.505120e+15  286480.0           5949937.0
# 5302  699.55  692.83  46559967  3.225830e+15  289445.0          18080082.0
# 5303  708.15  701.92  54060587  3.794635e+15  507747.0          17851331.0
# 5304  719.40  717.41  25939327  1.860920e+15  312079.0           7357520.0
# 5305  714.90  719.36  23011654  1.655365e+15  232879.0           6786072.0
#
#       %Deliverble
# 5301       0.2749
# ...

# %%
# Visualizing the using heatmap
sns.heatmap(axisbank.isnull(), yticklabels = False, cbar= False, cmap = 'viridis').set_title('No. of null values in data');

# %%
# Ploting heat map of correlation values between target columns vs null value columns
## Furst target column is : Volumn
null_cols = ['Volume','Trades','Deliverable Volume','%Deliverble']
corr_1 = axisbank[null_cols].corr()
sns.heatmap(corr_1, annot  = True);

# %%
 # Ploting heat map of correlation values between target columns vs null value columns
## Furst target column is : Open
null_cols = ['Open','Trades','Deliverable Volume','%Deliverble']
corr_1 = asianpaint[null_cols].corr()
sns.heatmap(corr_1, annot = True);

# %% [markdown]
# CHECK SHAPE ALL

# %%
hdfcbank.shape
# Out:
# (5306, 15)

# %%
adaniports.shape
# Out:
# (3322, 15)

# %%
asianpaint.shape
# Out:
# (5306, 15)

# %%
axisbank.shape
# Out:
# (5306, 15)

# %% [markdown]
# CHECK INFO ALL

# %%
hdfcbank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5306 non-null   object
#  1   Symbol              5306 non-null   object
#  2   Series              5306 non-null   object
#  3   Prev Close          5306 non-null   float64
#  4   Open                5306 non-null   float64
#  5   High                5306 non-null   float64
#  6   Low                 5306 non-null   float64
#  7   Last                5306 non-null   float64
#  8   Close               5306 non-null   float64
#  9   VWAP                5306 non-null   float64
#  10  Volume              5306 non-null   int64
#  11  Turnover            5306 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4797 non-null   float64
#  14  %Deliverble         4797 non-null   float64
# ...

# %%
adaniports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3322 entries, 0 to 3321
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                3322 non-null   object
#  1   Symbol              3322 non-null   object
#  2   Series              3322 non-null   object
#  3   Prev Close          3322 non-null   float64
#  4   Open                3322 non-null   float64
#  5   High                3322 non-null   float64
#  6   Low                 3322 non-null   float64
#  7   Last                3322 non-null   float64
#  8   Close               3322 non-null   float64
#  9   VWAP                3322 non-null   float64
#  10  Volume              3322 non-null   int64
#  11  Turnover            3322 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  3322 non-null   int64
#  14  %Deliverble         3322 non-null   float64
# ...

# %%
asianpaint.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5306 non-null   object
#  1   Symbol              5306 non-null   object
#  2   Series              5306 non-null   object
#  3   Prev Close          5306 non-null   float64
#  4   Open                5306 non-null   float64
#  5   High                5306 non-null   float64
#  6   Low                 5306 non-null   float64
#  7   Last                5306 non-null   float64
#  8   Close               5306 non-null   float64
#  9   VWAP                5306 non-null   float64
#  10  Volume              5306 non-null   int64
#  11  Turnover            5306 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4797 non-null   float64
#  14  %Deliverble         4797 non-null   float64
# ...

# %%
axisbank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5306 entries, 0 to 5305
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5306 non-null   object
#  1   Symbol              5306 non-null   object
#  2   Series              5306 non-null   object
#  3   Prev Close          5306 non-null   float64
#  4   Open                5306 non-null   float64
#  5   High                5306 non-null   float64
#  6   Low                 5306 non-null   float64
#  7   Last                5306 non-null   float64
#  8   Close               5306 non-null   float64
#  9   VWAP                5306 non-null   float64
#  10  Volume              5306 non-null   int64
#  11  Turnover            5306 non-null   float64
#  12  Trades              2456 non-null   float64
#  13  Deliverable Volume  4797 non-null   float64
#  14  %Deliverble         4797 non-null   float64
# ...

# %%
hdfcbank['Date'] = pd.to_datetime(adaniports['Date'])

# %%
adaniports['Date'] = pd.to_datetime(adaniports['Date'])

# %%
asianpaint['Date'] = pd.to_datetime(asianpaint['Date'])

# %%
axisbank['Date'] = pd.to_datetime(axisbank['Date'])

# %%
hdfcbank
# Out:
#            Date Symbol Series  Prev Close     Open     High      Low     Last  \
# 0    2007-11-27   HDFC     EQ      271.75   293.50   293.50   293.50   293.50
# 1    2007-11-28   HDFC     EQ      293.50   317.00   317.00   297.00   304.00
# 2    2007-11-29   HDFC     EQ      304.05   290.00   303.90   285.00   295.00
# 3    2007-11-30   HDFC     EQ      292.80   301.00   314.00   295.00   296.00
# 4    2007-12-03   HDFC     EQ      296.45   290.00   296.35   281.00   287.10
# ...         ...    ...    ...         ...      ...      ...      ...      ...
# 5301        NaT   HDFC     EQ     2497.35  2500.00  2534.10  2483.20  2502.00
# 5302        NaT   HDFC     EQ     2509.80  2494.15  2526.80  2486.25  2514.00
# 5303        NaT   HDFC     EQ     2518.40  2516.10  2609.00  2508.30  2575.00
# 5304        NaT   HDFC     EQ     2577.00  2590.90  2628.00  2533.00  2539.70
# 5305        NaT   HDFC     EQ     2538.85  2503.10  2525.00  2411.10  2433.25
#
# ...

# %%
adaniports
# Out:
#            Date      Symbol Series  Prev Close    Open     High     Low  \
# 0    2007-11-27  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.00
# 1    2007-11-28  MUNDRAPORT     EQ      962.90  984.00   990.00  874.00
# 2    2007-11-29  MUNDRAPORT     EQ      893.90  909.00   914.75  841.00
# 3    2007-11-30  MUNDRAPORT     EQ      884.20  890.00   958.00  890.00
# 4    2007-12-03  MUNDRAPORT     EQ      921.55  939.75   995.00  922.00
# ...         ...         ...    ...         ...     ...      ...     ...
# 3317 2021-04-26  ADANIPORTS     EQ      725.35  733.00   739.65  728.90
# 3318 2021-04-27  ADANIPORTS     EQ      730.75  735.00   757.50  727.35
# 3319 2021-04-28  ADANIPORTS     EQ      749.15  755.00   760.00  741.10
# 3320 2021-04-29  ADANIPORTS     EQ      746.25  753.20   765.85  743.40
# 3321 2021-04-30  ADANIPORTS     EQ      746.75  739.00   759.45  724.50
#
#        Last   Close    VWAP    Volume      Turnover    Trades  \
# ...

# %%
asianpaint
# Out:
#            Date      Symbol Series  Prev Close    Open     High      Low  \
# 0    2000-01-03  ASIANPAINT     EQ      361.20   370.0   390.00   370.00
# 1    2000-01-04  ASIANPAINT     EQ      381.65   380.0   392.00   375.00
# 2    2000-01-05  ASIANPAINT     EQ      385.55   371.5   390.00   371.50
# 3    2000-01-06  ASIANPAINT     EQ      383.00   384.9   384.90   374.50
# 4    2000-01-07  ASIANPAINT     EQ      377.50   376.0   390.00   370.00
# ...         ...         ...    ...         ...     ...      ...      ...
# 5301 2021-04-26  ASIANPAINT     EQ     2517.95  2530.0  2575.00  2530.00
# 5302 2021-04-27  ASIANPAINT     EQ     2557.90  2545.0  2579.90  2534.00
# 5303 2021-04-28  ASIANPAINT     EQ     2574.35  2588.0  2620.25  2575.00
# 5304 2021-04-29  ASIANPAINT     EQ     2614.55  2630.0  2642.00  2570.00
# 5305 2021-04-30  ASIANPAINT     EQ     2613.45  2595.0  2605.80  2524.05
#
#         Last    Close     VWAP   Volume      Turnover   Trades  \
# ...

# %%
axisbank
# Out:
#            Date    Symbol Series  Prev Close   Open    High     Low    Last  \
# 0    2000-01-03   UTIBANK     EQ       24.70   26.7   26.70   26.70   26.70
# 1    2000-01-04   UTIBANK     EQ       26.70   27.0   28.70   26.50   27.00
# 2    2000-01-05   UTIBANK     EQ       26.85   26.0   27.75   25.50   26.40
# 3    2000-01-06   UTIBANK     EQ       26.30   25.8   27.00   25.80   25.90
# 4    2000-01-07   UTIBANK     EQ       25.95   25.0   26.00   24.25   25.00
# ...         ...       ...    ...         ...    ...     ...     ...     ...
# 5301 2021-04-26  AXISBANK     EQ      671.35  694.0  703.80  684.50  699.50
# 5302 2021-04-27  AXISBANK     EQ      700.45  691.1  703.90  684.10  700.90
# 5303 2021-04-28  AXISBANK     EQ      699.55  708.0  712.50  688.15  705.95
# 5304 2021-04-29  AXISBANK     EQ      708.15  712.0  726.90  707.00  717.10
# 5305 2021-04-30  AXISBANK     EQ      719.40  705.0  729.85  705.00  711.65
#
# ...

# %%
rows_columns = f"NO. Of Rows: {hdfcbank.count()[0]}\nNO. of Columns: {len(hdfcbank.columns)}"
print(rows_columns)
# Out:
# NO. Of Rows: 3322
# NO. of Columns: 15

# %%
rows_columns = f"NO. Of Rows: {adaniports.count()[0]}\nNO. of Columns: {len(adaniports.columns)}"
print(rows_columns)
# Out:
# NO. Of Rows: 3322
# NO. of Columns: 15

# %%
rows_columns = f"NO. Of Rows: {asianpaint.count()[0]}\nNO. of Columns: {len(asianpaint.columns)}"
print(rows_columns)
# Out:
# NO. Of Rows: 5306
# NO. of Columns: 15

# %%
rows_columns = f"NO. Of Rows: {axisbank.count()[0]}\nNO. of Columns: {len(axisbank.columns)}"
print(rows_columns)
# Out:
# NO. Of Rows: 5306
# NO. of Columns: 12

# %% [markdown]
# CLEANING DATA POINTS

# %%
print("hdfcbank: ", hdfcbank.isnull().sum())
# Out:
# hdfcbank:  Date                  1984
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     509
# %Deliverble            509
# dtype: int64

# %%
print("adaniports: ", adaniports.isnull().sum())
# Out:
# adaniports:  Date                    0
# Symbol                  0
# Series                  0
# Prev Close              0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# VWAP                    0
# Volume                  0
# Turnover                0
# Trades                866
# Deliverable Volume      0
# %Deliverble             0
# dtype: int64

# %%
print("asianpaint: ", asianpaint.isnull().sum())
# Out:
# asianpaint:  Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     509
# %Deliverble            509
# dtype: int64

# %%
print("axisbank: ", axisbank.isnull().sum())
# Out:
# axisbank:  Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     509
# %Deliverble            509
# dtype: int64

# %% [markdown]
# Dropping Null Values

# %%
adaniports = adaniports.drop(['Trades'], axis = 1)
asianpaint = asianpaint.drop(['Trades', 'Deliverable Volume', '%Deliverble'], axis = 1)
axisbank = axisbank.drop(['Trades', 'Deliverable Volume', '%Deliverble'], axis = 1)

# %% [markdown]
# Now Checking Duplicates

# %%
hdfcbank.duplicated().sum()
# Out:
# 0

# %%
adaniports.duplicated().sum()
# Out:
# 0

# %%
asianpaint.duplicated().sum()
# Out:
# 0

# %%
axisbank.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Checking Shape

# %%
hdfcbank.shape
# Out:
# (5306, 15)

# %%
adaniports.shape
# Out:
# (3322, 14)

# %%
asianpaint.shape
# Out:
# (5306, 12)

# %%
axisbank.shape
# Out:
# (5306, 12)

# %% [markdown]
# Checking Columns

# %%
hdfcbank.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
adaniports.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
asianpaint.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover'],
#       dtype='object')

# %%
axisbank.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover'],
#       dtype='object')

# %%
hdfcbank.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5306.000000  5306.000000  5306.000000  5306.000000  5306.000000
# mean   1283.666114  1284.393074  1304.269732  1263.297842  1283.885017
# std     709.395090   709.703665   721.308080   697.450309   709.250204
# min     271.750000   284.000000   290.500000   273.250000   282.850000
# 25%     668.650000   669.712500   677.512500   660.000000   669.000000
# 50%    1136.275000  1135.400000  1156.725000  1119.000000  1135.000000
# 75%    1811.475000  1813.812500  1835.000000  1783.075000  1812.000000
# max    3180.150000  3148.000000  3262.000000  3100.550000  3178.000000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  5306.000000  5306.000000  5.306000e+03  5.306000e+03    2456.000000
# mean   1284.071005  1283.664578  1.848187e+06  2.620759e+14  102159.051303
# std     709.430515   709.109622  2.991387e+06  3.607844e+14   57948.603200
# ...

# %%
hdfcbank.describe().round(2)
# Out:
#        Prev Close     Open     High      Low     Last    Close     VWAP  \
# count     5306.00  5306.00  5306.00  5306.00  5306.00  5306.00  5306.00
# mean      1283.67  1284.39  1304.27  1263.30  1283.89  1284.07  1283.66
# std        709.40   709.70   721.31   697.45   709.25   709.43   709.11
# min        271.75   284.00   290.50   273.25   282.85   283.85   283.60
# 25%        668.65   669.71   677.51   660.00   669.00   668.66   668.26
# 50%       1136.28  1135.40  1156.72  1119.00  1135.00  1136.68  1136.72
# 75%       1811.48  1813.81  1835.00  1783.07  1812.00  1811.79  1811.68
# max       3180.15  3148.00  3262.00  3100.55  3178.00  3180.15  3166.58
#
#              Volume      Turnover     Trades  Deliverable Volume  %Deliverble
# count  5.306000e+03  5.306000e+03    2456.00        4.797000e+03      4797.00
# mean   1.848187e+06  2.620759e+14  102159.05        1.329440e+06         0.65
# std    2.991387e+06  3.607844e+14   57948.60        2.555073e+06         0.13
# ...

# %%
adaniports.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  3322.000000  3322.000000  3322.000000  3322.000000  3322.000000
# mean    344.114314   344.763019   351.608007   337.531969   344.239539
# std     192.936882   193.619992   198.617808   188.676614   193.187813
# min     108.000000   108.000000   110.450000   105.650000   108.000000
# 25%     164.312500   164.850000   168.000000   161.600000   164.075000
# 50%     324.700000   325.750000   331.275000   319.850000   325.000000
# 75%     400.912500   401.000000   407.187500   395.000000   400.912500
# max    1307.450000  1310.250000  1324.000000  1270.000000  1308.000000
#
#              Close         VWAP        Volume      Turnover  \
# count  3322.000000  3322.000000  3.322000e+03  3.322000e+03
# mean    344.201626   344.853182  2.954564e+06  1.070144e+14
# std     193.045886   193.841305  4.104227e+06  2.625564e+14
# min     108.000000   108.340000  1.236600e+04  2.415857e+11
# ...

# %%
adaniports.describe().round(2)
# Out:
#        Prev Close     Open     High      Low     Last    Close     VWAP  \
# count     3322.00  3322.00  3322.00  3322.00  3322.00  3322.00  3322.00
# mean       344.11   344.76   351.61   337.53   344.24   344.20   344.85
# std        192.94   193.62   198.62   188.68   193.19   193.05   193.84
# min        108.00   108.00   110.45   105.65   108.00   108.00   108.34
# 25%        164.31   164.85   168.00   161.60   164.08   164.31   164.86
# 50%        324.70   325.75   331.28   319.85   325.00   324.70   325.76
# 75%        400.91   401.00   407.19   395.00   400.91   400.91   400.61
# max       1307.45  1310.25  1324.00  1270.00  1308.00  1307.45  1302.15
#
#             Volume      Turnover  Deliverable Volume  %Deliverble
# count      3322.00  3.322000e+03             3322.00      3322.00
# mean    2954563.92  1.070144e+14          1207441.07         0.45
# std     4104226.70  2.625564e+14          1398640.16         0.16
# ...

# %%
asianpaint.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5306.000000  5306.000000  5306.000000  5306.000000  5306.000000
# mean   1247.000952  1247.683952  1264.625349  1230.900697  1247.317132
# std    1074.399506  1074.025577  1087.238871  1062.629409  1074.432667
# min     210.750000   210.000000   215.750000   204.000000   210.600000
# 25%     415.737500   415.000000   424.950000   410.000000   416.000000
# 50%     889.375000   890.000000   903.975000   878.075000   890.000000
# 75%    1599.037500  1599.800000  1629.675000  1573.037500  1602.500000
# max    5213.100000  5221.100000  5247.750000  5150.050000  5221.100000
#
#              Close         VWAP        Volume      Turnover
# count  5306.000000  5306.000000  5.306000e+03  5.306000e+03
# mean   1247.410903  1247.799926  5.096721e+05  6.942919e+13
# std    1074.476439  1075.057438  8.535993e+05  1.443973e+14
# min     210.750000   212.220000  2.500000e+01  1.278415e+09
# ...

# %%
asianpaint.describe().round(2)
# Out:
#        Prev Close     Open     High      Low     Last    Close     VWAP  \
# count     5306.00  5306.00  5306.00  5306.00  5306.00  5306.00  5306.00
# mean      1247.00  1247.68  1264.63  1230.90  1247.32  1247.41  1247.80
# std       1074.40  1074.03  1087.24  1062.63  1074.43  1074.48  1075.06
# min        210.75   210.00   215.75   204.00   210.60   210.75   212.22
# 25%        415.74   415.00   424.95   410.00   416.00   416.26   415.69
# 50%        889.38   890.00   903.98   878.08   890.00   889.47   888.35
# 75%       1599.04  1599.80  1629.68  1573.04  1602.50  1600.76  1600.98
# max       5213.10  5221.10  5247.75  5150.05  5221.10  5213.10  5175.79
#
#             Volume      Turnover
# count      5306.00  5.306000e+03
# mean     509672.09  6.942919e+13
# std      853599.26  1.443973e+14
# min          25.00  1.278415e+09
# 25%       13707.50  7.538133e+11
# 50%       57136.00  1.109437e+13
# 75%      807790.50  7.761479e+13
# max    11545936.00  2.216650e+15

# %%
axisbank.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5306.000000  5306.000000  5306.000000  5306.000000  5306.000000
# mean    585.763852   586.507388   596.476187   575.571598   585.897399
# std     436.714128   436.602194   443.044833   430.108921   436.609147
# min      22.150000    21.000000    23.700000    21.000000    22.150000
# 25%     230.950000   232.000000   235.125000   227.075000   230.550000
# 50%     519.450000   520.100000   528.400000   512.025000   519.425000
# 75%     877.312500   880.075000   897.987500   852.762500   877.275000
# max    2023.350000  2034.400000  2043.050000  2002.600000  2022.550000
#
#              Close         VWAP        Volume      Turnover
# count  5306.000000  5306.000000  5.306000e+03  5.306000e+03
# mean    585.893931   586.077778  4.527938e+06  2.739871e+14
# std     436.649765   436.611987  8.101940e+06  4.122431e+14
# min      22.150000    22.170000  2.850000e+03  8.275250e+09
# ...

# %%
axisbank.describe().round(2)
# Out:
#        Prev Close     Open     High      Low     Last    Close     VWAP  \
# count     5306.00  5306.00  5306.00  5306.00  5306.00  5306.00  5306.00
# mean       585.76   586.51   596.48   575.57   585.90   585.89   586.08
# std        436.71   436.60   443.04   430.11   436.61   436.65   436.61
# min         22.15    21.00    23.70    21.00    22.15    22.15    22.17
# 25%        230.95   232.00   235.12   227.08   230.55   230.98   231.12
# 50%        519.45   520.10   528.40   512.02   519.42   519.50   519.51
# 75%        877.31   880.08   897.99   852.76   877.28   877.31   875.81
# max       2023.35  2034.40  2043.05  2002.60  2022.55  2023.35  2020.31
#
#              Volume      Turnover
# count  5.306000e+03  5.306000e+03
# mean   4.527938e+06  2.739871e+14
# std    8.101940e+06  4.122431e+14
# min    2.850000e+03  8.275250e+09
# 25%    2.842172e+05  5.868745e+12
# 50%    1.656966e+06  1.653257e+14
# 75%    5.515245e+06  3.456528e+14
# max    1.205419e+08  7.179550e+15

# %% [markdown]
# describing Differently

# %%
numeric_columns = hdfcbank.select_dtypes(include=[np.number])
summary_stats = numeric_columns.describe()

# %%
numeric_columns
# Out:
#       Prev Close     Open     High      Low     Last    Close     VWAP  \
# 0         271.75   293.50   293.50   293.50   293.50   293.50   293.50
# 1         293.50   317.00   317.00   297.00   304.00   304.05   303.62
# 2         304.05   290.00   303.90   285.00   295.00   292.80   294.53
# 3         292.80   301.00   314.00   295.00   296.00   296.45   300.14
# 4         296.45   290.00   296.35   281.00   287.10   286.55   288.80
# ...          ...      ...      ...      ...      ...      ...      ...
# 5301     2497.35  2500.00  2534.10  2483.20  2502.00  2509.80  2508.07
# 5302     2509.80  2494.15  2526.80  2486.25  2514.00  2518.40  2509.18
# 5303     2518.40  2516.10  2609.00  2508.30  2575.00  2577.00  2574.21
# 5304     2577.00  2590.90  2628.00  2533.00  2539.70  2538.85  2569.65
# 5305     2538.85  2503.10  2525.00  2411.10  2433.25  2420.10  2445.94
#
#        Volume      Turnover    Trades  Deliverable Volume  %Deliverble
# ...

# %%
summary_stats
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5306.000000  5306.000000  5306.000000  5306.000000  5306.000000
# mean   1283.666114  1284.393074  1304.269732  1263.297842  1283.885017
# std     709.395090   709.703665   721.308080   697.450309   709.250204
# min     271.750000   284.000000   290.500000   273.250000   282.850000
# 25%     668.650000   669.712500   677.512500   660.000000   669.000000
# 50%    1136.275000  1135.400000  1156.725000  1119.000000  1135.000000
# 75%    1811.475000  1813.812500  1835.000000  1783.075000  1812.000000
# max    3180.150000  3148.000000  3262.000000  3100.550000  3178.000000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  5306.000000  5306.000000  5.306000e+03  5.306000e+03    2456.000000
# mean   1284.071005  1283.664578  1.848187e+06  2.620759e+14  102159.051303
# std     709.430515   709.109622  2.991387e+06  3.607844e+14   57948.603200
# ...

# %%
numeric_columns = adaniports.select_dtypes(include=[np.number])
summary_stats = numeric_columns.describe()

# %%
numeric_columns

# %%
summary_stats
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  3322.000000  3322.000000  3322.000000  3322.000000  3322.000000
# mean    344.114314   344.763019   351.608007   337.531969   344.239539
# std     192.936882   193.619992   198.617808   188.676614   193.187813
# min     108.000000   108.000000   110.450000   105.650000   108.000000
# 25%     164.312500   164.850000   168.000000   161.600000   164.075000
# 50%     324.700000   325.750000   331.275000   319.850000   325.000000
# 75%     400.912500   401.000000   407.187500   395.000000   400.912500
# max    1307.450000  1310.250000  1324.000000  1270.000000  1308.000000
#
#              Close         VWAP        Volume      Turnover  \
# count  3322.000000  3322.000000  3.322000e+03  3.322000e+03
# mean    344.201626   344.853182  2.954564e+06  1.070144e+14
# std     193.045886   193.841305  4.104227e+06  2.625564e+14
# min     108.000000   108.340000  1.236600e+04  2.415857e+11
# ...

# %%
numeric_columns = asianpaint.select_dtypes(include=[np.number])
summary_stats = numeric_columns.describe()

# %%
numeric_columns
# Out:
#       Prev Close    Open     High      Low    Last    Close     VWAP   Volume  \
# 0         361.20   370.0   390.00   370.00   385.0   381.65   380.54     3318
# 1         381.65   380.0   392.00   375.00   390.0   385.55   383.50     4818
# 2         385.55   371.5   390.00   371.50   383.0   383.00   379.81     2628
# 3         383.00   384.9   384.90   374.50   375.1   377.50   379.88     3354
# 4         377.50   376.0   390.00   370.00   389.0   385.70   383.38     9589
# ...          ...     ...      ...      ...     ...      ...      ...      ...
# 5301     2517.95  2530.0  2575.00  2530.00  2558.0  2557.90  2557.47  1103980
# 5302     2557.90  2545.0  2579.90  2534.00  2571.0  2574.35  2560.55   866331
# 5303     2574.35  2588.0  2620.25  2575.00  2612.0  2614.55  2605.91  1065561
# 5304     2614.55  2630.0  2642.00  2570.00  2613.0  2613.45  2607.33  1295346
# 5305     2613.45  2595.0  2605.80  2524.05  2529.0  2536.40  2558.66  1384907
#
#           Turnover
# ...

# %%
summary_stats
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5306.000000  5306.000000  5306.000000  5306.000000  5306.000000
# mean   1247.000952  1247.683952  1264.625349  1230.900697  1247.317132
# std    1074.399506  1074.025577  1087.238871  1062.629409  1074.432667
# min     210.750000   210.000000   215.750000   204.000000   210.600000
# 25%     415.737500   415.000000   424.950000   410.000000   416.000000
# 50%     889.375000   890.000000   903.975000   878.075000   890.000000
# 75%    1599.037500  1599.800000  1629.675000  1573.037500  1602.500000
# max    5213.100000  5221.100000  5247.750000  5150.050000  5221.100000
#
#              Close         VWAP        Volume      Turnover
# count  5306.000000  5306.000000  5.306000e+03  5.306000e+03
# mean   1247.410903  1247.799926  5.096721e+05  6.942919e+13
# std    1074.476439  1075.057438  8.535993e+05  1.443973e+14
# min     210.750000   212.220000  2.500000e+01  1.278415e+09
# ...

# %%
numeric_columns = axisbank.select_dtypes(include=[np.number])
summary_stats = numeric_columns.describe()

# %%
numeric_columns
# Out:
#       Prev Close   Open    High     Low    Last   Close    VWAP    Volume  \
# 0          24.70   26.7   26.70   26.70   26.70   26.70   26.70    112100
# 1          26.70   27.0   28.70   26.50   27.00   26.85   27.24    234500
# 2          26.85   26.0   27.75   25.50   26.40   26.30   26.24    170100
# 3          26.30   25.8   27.00   25.80   25.90   25.95   26.27    102100
# 4          25.95   25.0   26.00   24.25   25.00   24.80   25.04     62600
# ...          ...    ...     ...     ...     ...     ...     ...       ...
# 5301      671.35  694.0  703.80  684.50  699.50  700.45  695.33  21646184
# 5302      700.45  691.1  703.90  684.10  700.90  699.55  692.83  46559967
# 5303      699.55  708.0  712.50  688.15  705.95  708.15  701.92  54060587
# 5304      708.15  712.0  726.90  707.00  717.10  719.40  717.41  25939327
# 5305      719.40  705.0  729.85  705.00  711.65  714.90  719.36  23011654
#
#           Turnover
# 0     2.993070e+11
# 1     6.387275e+11
# ...

# %%
summary_stats
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5306.000000  5306.000000  5306.000000  5306.000000  5306.000000
# mean    585.763852   586.507388   596.476187   575.571598   585.897399
# std     436.714128   436.602194   443.044833   430.108921   436.609147
# min      22.150000    21.000000    23.700000    21.000000    22.150000
# 25%     230.950000   232.000000   235.125000   227.075000   230.550000
# 50%     519.450000   520.100000   528.400000   512.025000   519.425000
# 75%     877.312500   880.075000   897.987500   852.762500   877.275000
# max    2023.350000  2034.400000  2043.050000  2002.600000  2022.550000
#
#              Close         VWAP        Volume      Turnover
# count  5306.000000  5306.000000  5.306000e+03  5.306000e+03
# mean    585.893931   586.077778  4.527938e+06  2.739871e+14
# std     436.649765   436.611987  8.101940e+06  4.122431e+14
# min      22.150000    22.170000  2.850000e+03  8.275250e+09
# ...

# %% [markdown]
# Distribution of Numeric Columns

# %%
hdfcbank[numeric_columns.columns].hist(bins=20, figsize=(12, 8))
plt.tight_layout()
plt.show()

# %%
adaniports[numeric_columns.columns].hist(bins=20, figsize=(12, 8))
plt.tight_layout()
plt.show()

# %%
asianpaint[numeric_columns.columns].hist(bins=20, figsize=(12, 8))
plt.tight_layout()
plt.show()

# %%
axisbank[numeric_columns.columns].hist(bins=20, figsize=(12, 8))
plt.tight_layout()
plt.show()

# %% [markdown]
# relationships between columns using scatter plots (hdfcbank)

# %%
sns.scatterplot(x='Open', y='Close', data=hdfcbank)
plt.xlabel('Open Price')
plt.ylabel('Close Price')
plt.title('Relationship between Open and Close Prices')
plt.show()

# %% [markdown]
# relationships between columns using bar charts (hdfcbank)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Symbol', y='Volume', data=adaniports)
plt.xlabel('Symbol')
plt.ylabel('Volume')
plt.title('Volume by Symbol')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# relationships between columns using scatter plots (adaniports)

# %%
sns.scatterplot(x='Open', y='Close', data=adaniports)
plt.xlabel('Open Price')
plt.ylabel('Close Price')
plt.title('Relationship between Open and Close Prices')
plt.show()

# %% [markdown]
# relationships between columns using bar charts (adaniports)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Symbol', y='Volume', data=adaniports)
plt.xlabel('Symbol')
plt.ylabel('Volume')
plt.title('Volume by Symbol')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# relationships between columns using scatter plots (asianpaint)

# %%
sns.scatterplot(x='Open', y='Close', data=asianpaint)
plt.xlabel('Open Price')
plt.ylabel('Close Price')
plt.title('Relationship between Open and Close Prices')
plt.show()

# %% [markdown]
# relationships between columns using bar charts (asianpaint)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Symbol', y='Volume', data=asianpaint)
plt.xlabel('Symbol')
plt.ylabel('Volume')
plt.title('Volume by Symbol')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# relationships between columns using scatter plots (axisbank)

# %%
sns.scatterplot(x='Open', y='Close', data=axisbank)
plt.xlabel('Open Price')
plt.ylabel('Close Price')
plt.title('Relationship between Open and Close Prices')
plt.show()

# %% [markdown]
# relationships between columns using bar charts (axisbank)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Symbol', y='Volume', data=axisbank)
plt.xlabel('Symbol')
plt.ylabel('Volume')
plt.title('Volume by Symbol')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# comparing the 'Close' prices of Hdfc Bank, Adani Ports, Asian Paints, and Axis Bank

# %%
plt.figure(figsize=(10, 6))
plt.hist(hdfcbank['Close'], bins=20, alpha=0.5, label='Hdfc Bank')
plt.hist(adaniports['Close'], bins=20, alpha=0.5, label='Adani Ports')
plt.hist(asianpaint['Close'], bins=20, alpha=0.5, label='Asian Paints')
plt.hist(axisbank['Close'], bins=20, alpha=0.5, label='Axis Bank')
plt.xlabel('Close Price')
plt.ylabel('Count')
plt.title('Distribution of Close Prices for Different Companies')
plt.legend()
plt.show()

# %% [markdown]
# What is the average daily volume traded for each company?

# %%
avg_volume_hdfcbank = hdfcbank['Volume'].mean()
avg_volume_adaniports = adaniports['Volume'].mean()
avg_volume_asianpaint = asianpaint['Volume'].mean()
avg_volume_axisbank = axisbank['Volume'].mean()

print("Average Daily Volume Traded:")
print(f"Hdfc Bank: {avg_volume_hdfcbank}")
print(f"Adani Ports: {avg_volume_adaniports}")
print(f"Asian Paints: {avg_volume_asianpaint}")
print(f"Axis Bank: {avg_volume_axisbank}")
# Out:
# Average Daily Volume Traded:
# Hdfc Bank: 1848186.9159442142
# Adani Ports: 2954563.9217338953
# Asian Paints: 509672.0868827742
# Axis Bank: 4527937.646061063

# %% [markdown]
# How does the daily trading volume vary across the three companies?

# %%
plt.figure(figsize=(10, 6))
plt.bar(['Hdfc Bank', 'Adani Ports', 'Asian Paints', 'Axis Bank'], [avg_volume_hdfcbank, avg_volume_adaniports, avg_volume_asianpaint, avg_volume_axisbank])
plt.xlabel('Company')
plt.ylabel('Average Daily Volume')
plt.title('Average Daily Trading Volume Comparison')
plt.show()

# %% [markdown]
# Is there any relationship between the opening and closing prices for each company?

# %%
plt.figure(figsize=(10, 6))
plt.scatter(hdfcbank['Open'], hdfcbank['Close'], label='Hdfc BANK')
plt.scatter(adaniports['Open'], adaniports['Close'], label='Adani Ports')
plt.scatter(asianpaint['Open'], asianpaint['Close'], label='Asian Paints')
plt.scatter(axisbank['Open'], axisbank['Close'], label='Axis Bank')
plt.xlabel('Opening Price')
plt.ylabel('Closing Price')
plt.title('Relationship between Opening and Closing Prices')
plt.legend()
plt.show()

# %% [markdown]
# How does the trading volume vary over time for each company?

# %%
plt.figure(figsize=(10, 6))
plt.plot(hdfcbank['Date'], hdfcbank['Volume'], label='Hdfc Bank')
plt.plot(adaniports['Date'], adaniports['Volume'], label='Adani Ports')
plt.plot(asianpaint['Date'], asianpaint['Volume'], label='Asian Paints')
plt.plot(axisbank['Date'], axisbank['Volume'], label='Axis Bank')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title('Trading Volume Variation Over Time')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# BOXPLOT

# %%
plt.boxplot(hdfcbank['Open'])
plt.show()

# %%
plt.boxplot(adaniports['High'])
plt.show()

# %%
plt.boxplot(asianpaint['Close'])
plt.show()

# %%
plt.boxplot(axisbank['Low'])
plt.show()

# %% [markdown]
# PIE CHART

# %%
a=[10,20,60,50]
label=['High', 'Low', 'Open', 'Close']
cols=['green', 'red', 'yellow', 'blue']
plt.pie(a,labels=label,colors=cols,startangle=120,explode=(0,0,0,0))
plt.show()

# %%
# select all rows by : and column 1
# by 1:2 representing features
X = hdfcbank[:, 1:2].astype(int)

# print X
print(X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), slice(1, 2, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-49-176f73918d22> in <cell line: 3>()
#       1 # select all rows by : and column 1
# ...

# %%
# Visualizing the opening prices of the data.
plt.figure(figsize=(16,8))
plt.title('Apple')
plt.xlabel('Days')
plt.ylabel('Opening Price USD ($)')
plt.plot(hdfcbank['Open'])
plt.show()

# %%
# Visualizing the high prices of the data.
plt.figure(figsize=(16,8))
plt.title('Apple')
plt.xlabel('Days')
plt.ylabel('High Price USD ($)')
plt.plot(hdfcbank['High'])
plt.show()

# %%
# Visualizing the low prices of the data.
plt.figure(figsize=(16,8))
plt.title('Apple')
plt.xlabel('Days')
plt.ylabel('Low Price USD ($)')
plt.plot(hdfcbank['Low'])
plt.show()

# %%
# Visualizing the closing prices of the data.
plt.figure(figsize=(16,8))
plt.title('Apple')
plt.xlabel('Days')
plt.ylabel('Closing Price USD ($)')
plt.plot(hdfcbank['Close'])
plt.show()

# %%
hdfcbank2 = hdfcbank['Close']

# %%
hdfcbank2.tail()
# Out:
# 5301    2509.80
# 5302    2518.40
# 5303    2577.00
# 5304    2538.85
# 5305    2420.10
# Name: Close, dtype: float64

# %%
hdfcbank2 = pd.DataFrame(hdfcbank2)

# %%
hdfcbank2.tail()
# Out:
#         Close
# 5301  2509.80
# 5302  2518.40
# 5303  2577.00
# 5304  2538.85
# 5305  2420.10

# %%
# Prediction 100 days into the future.
future_days = 100
hdfcbank2['Prediction'] = hdfcbank2['Close'].shift(-future_days)

# %%
hdfcbank2.tail()
# Out:
#         Close  Prediction
# 5301  2509.80         NaN
# 5302  2518.40         NaN
# 5303  2577.00         NaN
# 5304  2538.85         NaN
# 5305  2420.10         NaN

# %%
X = np.array(hdfcbank2.drop(['Prediction'], 1))[:-future_days]
print(X)
# Out:
# [[ 293.5 ]
#  [ 304.05]
#  [ 292.8 ]
#  ...
#  [2256.25]
#  [2306.95]
#  [2276.35]]
# <ipython-input-37-6aa1b7f0a360>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = np.array(hdfcbank2.drop(['Prediction'], 1))[:-future_days]

# %%
y = np.array(hdfcbank2['Prediction'])[:-future_days]
print(y)
# Out:
# [ 543.65  478.45  496.35 ... 2577.   2538.85 2420.1 ]

# %%
# import the regressor
from sklearn.tree import DecisionTreeRegressor

# create a regressor object
regressor = DecisionTreeRegressor(random_state = 0)

# fit the regressor with X and Y data
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# predicting a new value

# test the output by changing values, like 3750
y_pred = regressor.predict([[3750]])

# print the predicted price
print("Predicted price: % d\n"% y_pred)
# Out:
# Predicted price:  2349

# %%
# arange for creating a range of values
# from min value of X to max value of X
# with a difference of 0.01 between two
# consecutive values
X_grid = np.arange(min(X), max(X), 0.01)

# reshape for reshaping the data into
# a len(X_grid)*1 array, i.e. to make
# a column out of the X_grid values
X_grid = X_grid.reshape((len(X_grid), 1))

# scatter plot for original data
plt.scatter(X, y, color = 'red')

# plot predicted data
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')

# specify title
plt.title('Profit to Production Cost (Decision Tree Regression)')

# specify X axis label
plt.xlabel('Production Cost')

# specify Y axis label
plt.ylabel('Profit')

# show the plot
plt.show()

# %%
# import export_graphviz
from sklearn.tree import export_graphviz

# export the decision tree to a tree.dot file
# for visualizing the plot easily anywhere
export_graphviz(regressor, out_file ='tree.dot',
               feature_names =['Production Cost'])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression

# %%
# Implementing Linear and Decision Tree Regression Algorithms.
tree = DecisionTreeRegressor().fit(x_train, y_train)
lr = LinearRegression().fit(x_train, y_train)

# %%
x_future = hdfcbank2.drop(['Prediction'], 1)[:-future_days]
x_future = x_future.tail(future_days)
x_future = np.array(x_future)
x_future
# Out:
# <ipython-input-43-ae7ccd87eb04>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_future = hdfcbank2.drop(['Prediction'], 1)[:-future_days]
# array([[1791.6 ],
#        [1789.9 ],
#        [1787.8 ],
#        [1805.85],
#        [1806.05],
#        [1883.65],
#        [1881.05],
#        [1875.8 ],
#        [1841.3 ],
#        [1850.75],
#        [1897.35],
#        [1877.3 ],
#        [1810.65],
#        [1781.95],
#        [1739.8 ],
#        [1781.1 ],
#        [1776.7 ],
#        [1783.75],
#        [1777.7 ],
#        [1798.95],
#        [1826.75],
#        [1814.2 ],
#        [1804.85],
#        [1791.7 ],
#        [1800.55],
#        [1820.7 ],
#        [1827.95],
#        [1785.15],
#        [1804.05],
#        [1829.85],
#        [1829.6 ],
#        [1816.  ],
#        [1864.1 ],
#        [1883.25],
#        [1832.6 ],
#        [1851.2 ],
#        [1827.2 ],
#        [1808.75],
# ...

# %%
tree_prediction = tree.predict(x_future)
print(tree_prediction)
# Out:
# [2638.85       2245.9        1923.55       1995.95       1660.25
#  2289.1        2295.9        2302.65       2350.35       2424.65
#  2494.6        2479.4        2414.8        1410.8        2403.05
#  2455.15       2476.45       2518.95       2518.05       2558.65
#  2568.75       2578.5        2651.85       2638.85       2661.35
#  2657.5        2751.2        2747.55       2670.9        1978.6
#  2632.75       2566.5        2656.95       2495.78333333 1816.1
#  2589.45       2551.4        2467.         2425.75       2377.8
#  2579.25       2659.         2579.25       2707.75       2721.5
#  2733.35       2707.75       2293.175      2760.6        2791.5
#  1959.95       2858.65       2265.6        2745.15       2741.3
#  2651.95       2628.6        1694.45       2747.55       2465.75
#  2606.         2564.         2654.9        2582.95       2424.95
#  2510.25       2577.3        2281.25       2568.         2535.5
#  2510.4        2515.55       2514.6        2531.65       2531.85
# ...

# %%
lr_prediction = lr.predict(x_future)
print(lr_prediction)
# Out:
# [1738.24200365 1736.84111523 1735.11060599 1749.98474488 1750.14955528
#  1814.09599172 1811.95345648 1807.6271834  1779.19738885 1786.9846804
#  1825.38550434 1808.86326142 1753.94019456 1730.2899017  1695.55610922
#  1729.58945748 1725.96362861 1731.77319533 1726.78768063 1744.29878597
#  1767.20743201 1756.86557921 1749.16069286 1738.32440885 1745.6172692
#  1762.22191732 1768.19629443 1732.92686815 1748.50145125 1769.76199326
#  1769.55598026 1758.34887284 1797.98577481 1813.76637092 1772.02813631
#  1787.35550381 1767.57825542 1752.37449573 1720.1952645  1737.82997764
#  1726.45805982 1712.81999896 1726.58166763 1718.91798388 1694.0728156
#  1711.17189493 1718.91798388 1699.3055459  1682.53608737 1669.47486292
#  1642.03393079 1635.64752766 1610.71995418 1623.20434222 1647.47267409
#  1673.5539204  1695.76212223 1737.45915424 1732.88566555 1855.91663154
#  1867.74177796 1868.15380397 1875.07584091 1881.46224403 1863.33309968
# ...

# %%
predictions = tree_prediction
valid = hdfcbank2[X.shape[0]:]
valid['Predictions'] = predictions
# Out:
# <ipython-input-46-2aa3056b9399>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
plt.figure(figsize=(16,8))
plt.title("Model")
plt.xlabel('Days')
plt.ylabel('Close Price USD ($)')
plt.plot(hdfcbank2['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(["Original", "Valid", 'Predicted'])
plt.show()

# %%
from sklearn import tree
X = [[0, 0], [1, 1]]
Y = [0, 1]
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, Y)

# %%
clf.predict([[2., 2.]])
# Out:
# array([1])

# %%
>>> clf.predict_proba([[2., 2.]])
array([[0., 1.]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b3eeb51cb2c9> in <cell line: 2>()
#       1 clf.predict_proba([[2., 2.]])
# ----> 2 array([[0., 1.]])
#
# NameError: name 'array' is not defined

# %%
from sklearn.datasets import load_iris
from sklearn import tree
iris = load_iris()
X, y = iris.data, iris.target
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'x[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
# ...

# %%
# Author: Issam H. Laradji
# License: BSD 3 clause

import numpy as np
from matplotlib import pyplot as plt
from matplotlib.colors import ListedColormap

from sklearn.datasets import make_circles, make_classification, make_moons
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

h = 0.02  # step size in the mesh

alphas = np.logspace(-1, 1, 5)

classifiers = []
names = []
for alpha in alphas:
    classifiers.append(
        make_pipeline(
            StandardScaler(),
            MLPClassifier(
                solver="lbfgs",
                alpha=alpha,
                random_state=1,
                max_iter=2000,
                early_stopping=True,
                hidden_layer_sizes=[10, 10],
            ),
        )
    )
    names.append(f"alpha {alpha:.2f}")

X, y = make_classification(
    n_features=2, n_redundant=0, n_informative=2, random_state=0, n_clusters_per_class=1
)
rng = np.random.RandomState(2)
X += 2 * rng.uniform(size=X.shape)
linearly_separable = (X, y)

datasets = [
    make_moons(noise=0.3, random_state=0),
    make_circles(noise=0.2, factor=0.5, random_state=1),
    linearly_separable,
]

figure = plt.figure(figsize=(17, 9))
i = 1
# iterate over datasets
for X, y in datasets:
    # split into training and test part
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.4, random_state=42
    )

    x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
    y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

    # just plot the dataset first
    cm = plt.cm.RdBu
    cm_bright = ListedColormap(["#FF0000", "#0000FF"])
    ax = plt.subplot(len(datasets), len(classifiers) + 1, i)
    # Plot the training points
    ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright)
    # and testing points
    ax.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright, alpha=0.6)
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xticks(())
    ax.set_yticks(())
    i += 1

    # iterate over classifiers
    for name, clf in zip(names, classifiers):
        ax = plt.subplot(len(datasets), len(classifiers) + 1, i)
        clf.fit(X_train, y_train)
        score = clf.score(X_test, y_test)

        # Plot the decision boundary. For that, we will assign a color to each
        # point in the mesh [x_min, x_max] x [y_min, y_max].
        if hasattr(clf, "decision_function"):
            Z = clf.decision_function(np.column_stack([xx.ravel(), yy.ravel()]))
        else:
            Z = clf.predict_proba(np.column_stack([xx.ravel(), yy.ravel()]))[:, 1]

        # Put the result into a color plot
        Z = Z.reshape(xx.shape)
        ax.contourf(xx, yy, Z, cmap=cm, alpha=0.8)

        # Plot also the training points
        ax.scatter(
            X_train[:, 0],
            X_train[:, 1],
            c=y_train,
            cmap=cm_bright,
            edgecolors="black",
            s=25,
        )
        # and testing points
        ax.scatter(
            X_test[:, 0],
            X_test[:, 1],
            c=y_test,
            cmap=cm_bright,
            alpha=0.6,
            edgecolors="black",
            s=25,
        )

        ax.set_xlim(xx.min(), xx.max())
        ax.set_ylim(yy.min(), yy.max())
        ax.set_xticks(())
        ax.set_yticks(())
        ax.set_title(name)
        ax.text(
            xx.max() - 0.3,
            yy.min() + 0.3,
            f"{score:.3f}".lstrip("0"),
            size=15,
            horizontalalignment="right",
        )
        i += 1

figure.subplots_adjust(left=0.02, right=0.98)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.decomposition import PCA

rng = np.random.RandomState(0)
n_samples = 500
cov = [[3, 3], [3, 4]]
X = rng.multivariate_normal(mean=[0, 0], cov=cov, size=n_samples)
pca = PCA(n_components=2).fit(X)


plt.scatter(X[:, 0], X[:, 1], alpha=0.3, label="samples")
for i, (comp, var) in enumerate(zip(pca.components_, pca.explained_variance_)):
    comp = comp * var  # scale component by its variance explanation power
    plt.plot(
        [0, comp[0]],
        [0, comp[1]],
        label=f"Component {i}",
        linewidth=5,
        color=f"C{i + 2}",
    )
plt.gca().set(
    aspect="equal",
    title="2-dimensional dataset with principal components",
    xlabel="first feature",
    ylabel="second feature",
)
plt.legend()
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import fetch_california_housing

# from sklearn.inspection import plot_partial_dependence
from sklearn.inspection import PartialDependenceDisplay

X, y = fetch_california_housing(return_X_y=True, as_frame=True)
features = ["MedInc", "AveOccup", "HouseAge", "AveRooms"]
est = RandomForestRegressor(n_estimators=10)
est.fit(X, y)

# plot_partial_dependence has been removed in version 1.2. From 1.2, use
# PartialDependenceDisplay instead.
# display = plot_partial_dependence(
display = PartialDependenceDisplay.from_estimator(
    est,
    X,
    features,
    kind="individual",
    subsample=50,
    n_jobs=3,
    grid_resolution=20,
    random_state=0,
)
display.figure_.suptitle(
    "Partial dependence of house value on non-location features\n"
    "for the California housing dataset, with BayesianRidge"
)
display.figure_.subplots_adjust(hspace=0.3)
