# %% [markdown]
# <a href="https://colab.research.google.com/github/tinkam17/Stock-prediction-model/blob/main/STUDENTS_PERFORMANCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
categorical_cols=df.select_dtypes(include='object'). columns

# %%
categorical_cols
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course'],
#       dtype='object')

# %%
for i in categorical_cols:
   print(df[i].unique)
# Out:
# <bound method Series.unique of 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object>
# <bound method Series.unique of 0      group B
# 1      group C
# 2      group B
# 3      group A
# 4      group C
#         ...
# 995    group E
# 996    group C
# 997    group C
# 998    group D
# 999    group D
# Name: race/ethnicity, Length: 1000, dtype: object>
# <bound method Series.unique of 0       bachelor's degree
# 1            some college
# 2         master's degree
# 3      associate's degree
# 4            some college
#               ...
# 995       master's degree
# 996           high school
# 997           high school
# 998          some college
# 999          some college
# Name: parental level of education, Length: 1000, dtype: object>
# <bound method Series.unique of 0          standard
# 1          standard
# ...

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(df['gender'])
# Out:
# <Axes: xlabel='count', ylabel='gender'>

# %% [markdown]
# ## How many of the students take preparatory classes

# %%
count_test=df['test preparation course'].value_counts()
labels=df['test preparation course'].value_counts().index
plt.figure(figsize=(6,6))
plt.pie(count_test,labels=labels,autopct='%1.1f%%')
plt.legend(labels)
plt.show()

# %%
df['average_score']= (df['math score']+df['reading score']+df['writing score'])/3

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# ##Student performance in subjects based on gender

# %%
sns.scatterplot(x=df['average_score'], y=df['math score'], hue=df['gender'])
# Out:
# <Axes: xlabel='average_score', ylabel='math score'>

# %%
sns.scatterplot(x=df['average_score'], y=df['reading score'], hue=df['gender'])
# Out:
# <Axes: xlabel='average_score', ylabel='reading score'>

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
gender = {
          'male' :1,
          'female':0
  }

# %%
race = {
        'group A' :0,
        'group B' :1,
        'group C' :2,
        'group D' :3,
        'group E' :4
}

# %%
df['gender']=df['gender'].map(gender)
df['race/ethnicity']=df['race/ethnicity'].map(race)

# %%
df
# Out:
#      gender  race/ethnicity parental level of education         lunch  \
# 0         0               1           bachelor's degree      standard
# 1         0               2                some college      standard
# 2         0               1             master's degree      standard
# 3         1               0          associate's degree  free/reduced
# 4         1               2                some college      standard
# ..      ...             ...                         ...           ...
# 995       0               4             master's degree      standard
# 996       1               2                 high school  free/reduced
# 997       0               2                 high school  free/reduced
# 998       0               3                some college      standard
# 999       0               3                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
level = {
     "bachelor's degree" :0,
     "some college" :1,
     "master's degree" :2,
     "associate's degree" :3,
     "high school" :4,
     "some high school" :5
}

# %%
df['parental level of education']=df['parental level of education'].map(level)

# %%
df
# Out:
#      gender  race/ethnicity  parental level of education         lunch  \
# 0         0               1                            0      standard
# 1         0               2                            1      standard
# 2         0               1                            2      standard
# 3         1               0                            3  free/reduced
# 4         1               2                            1      standard
# ..      ...             ...                          ...           ...
# 995       0               4                            2      standard
# 996       1               2                            4  free/reduced
# 997       0               2                            4  free/reduced
# 998       0               3                            1      standard
# 999       0               3                            1  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
df
# Out:
#      gender  race/ethnicity  parental level of education  math score  \
# 0         0               1                            0          72
# 1         0               2                            1          69
# 2         0               1                            2          90
# 3         1               0                            3          47
# 4         1               2                            1          76
# ..      ...             ...                          ...         ...
# 995       0               4                            2          88
# 996       1               2                            4          62
# 997       0               2                            4          59
# 998       0               3                            1          68
# 999       0               3                            1          77
#
#      reading score  writing score  average_score  lunch_standard  \
# 0               72             74      72.666667               1
# ...

# %%
x = df.drop(columns='average_score'). values

# %%
x
# Out:
# array([[ 0,  1,  0, ..., 74,  1,  1],
#        [ 0,  2,  1, ..., 88,  1,  0],
#        [ 0,  1,  2, ..., 93,  1,  1],
#        ...,
#        [ 0,  2,  4, ..., 65,  0,  0],
#        [ 0,  3,  1, ..., 77,  1,  0],
#        [ 0,  3,  1, ..., 86,  0,  1]])

# %%
y = df['average_score'].values

# %%
y
# Out:
# array([ 72.66666667,  82.33333333,  92.66666667,  49.33333333,
#         76.33333333,  77.33333333,  91.66666667,  40.66666667,
#         65.        ,  49.33333333,  54.66666667,  45.        ,
#         73.        ,  73.33333333,  53.66666667,  74.        ,
#         87.66666667,  26.        ,  44.66666667,  57.66666667,
#         66.        ,  70.        ,  50.33333333,  71.66666667,
#         75.        ,  73.        ,  59.33333333,  70.33333333,
#         68.33333333,  69.        ,  72.33333333,  63.        ,
#         64.33333333,  40.        ,  88.66666667,  80.33333333,
#         79.33333333,  57.66666667,  84.33333333,  56.66666667,
#         56.66666667,  66.33333333,  58.66666667,  63.33333333,
#         53.33333333,  58.66666667,  60.66666667,  71.        ,
#         69.        ,  82.66666667,  52.        ,  71.33333333,
#         46.33333333,  80.33333333,  80.66666667,  39.        ,
#         84.33333333,  52.        ,  58.33333333,   9.        ,
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor()

# %%
import numpy as np

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['gender'] = le.fit_transform(df['gender'])

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
predictions=model.predict(x_test)

# %%
predictions
# Out:
# array([86.49333333, 63.33      , 74.40333333, 75.03      , 81.94      ,
#        78.09      , 67.19666667, 59.07333333, 77.07666667, 49.28333333,
#        47.41333333, 27.79333333, 75.73      , 58.48      , 83.32333333,
#        74.75666667, 49.30666667, 47.99      , 52.76333333, 61.00666667,
#        72.94333333, 49.77      , 65.72      , 44.4       , 78.7       ,
#        77.31666667, 71.55666667, 49.77      , 43.46333333, 55.60333333,
#        59.92333333, 66.74666667, 60.53      , 73.21666667, 77.26666667,
#        51.95      , 75.67666667, 74.30333333, 75.05333333, 23.12      ,
#        78.22333333, 64.48333333, 65.31666667, 60.86      , 85.06333333,
#        64.52      , 70.91      , 29.89333333, 86.04      , 78.79      ,
#        71.54666667, 71.46      , 78.01333333, 53.56333333, 71.13666667,
#        72.        , 81.71333333, 54.64      , 82.48333333, 89.03      ,
#        43.73333333, 80.54666667, 78.75333333, 61.20666667, 87.58666667,
# ...

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(predictions,y_test))
# Out:
# 0.9937563688186138

# %%
sns.scatterplot(x=df['math score'], y=df['writing score'])
# Out:
# <Axes: xlabel='math score', ylabel='writing score'>

# %%
sns.regplot(x=df['math score'], y=df['writing score'])
# Out:
# <Axes: xlabel='math score', ylabel='writing score'>

# %%
sns.scatterplot(x=df['math score'], y=df['writing score'], hue=df['gender'])
# Out:
# <Axes: xlabel='math score', ylabel='writing score'>

# %%
sns.lmplot(x="math score", y="writing score", hue="gender", data=df)
